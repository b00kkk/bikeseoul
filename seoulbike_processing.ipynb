# %% [markdown]
# <a href="https://colab.research.google.com/github/qnrua0511/bikeseoul/blob/main/seoulbike_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 공공자전거 대여소 정보 전처리

# %%
rental_shop_col=['대여소번호','대여소명','자치구','상세주소','위도','경도','설치시','LCD','QR','운영방식']
rental_shop=pd.read_csv('/content/공공자전거 대여소 정보(23.12월 기준).csv',skiprows=4,encoding='euc-kr')
rental_shop.columns=rental_shop_col

# %%
rental_shop.head()
# Out:
#    대여소번호          대여소명  자치구                             상세주소         위도  \
# 0    301   경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞  37.575794
# 1    302   경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤  37.575947
# 2    303   광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원  37.571770
# 3    305        종로구청 옆  종로구               서울특별시 종로구 세종로 84-1  37.572559
# 4    307     서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞  37.570000
#
#            경도         설치시   LCD    QR 운영방식
# 0  126.971451  2015-10-07  20.0  20.0   QR
# 1  126.974060  2015-10-07  12.0  12.0   QR
# 2  126.974663  2015-10-07   8.0   8.0   QR
# 3  126.978332  2015-01-07  16.0  16.0   QR
# 4  126.971100  2015-10-07  11.0  11.0   QR

# %%
rental_shop_add=rental_shop.iloc[:,0:6]
rental_shop_add.to_csv('rental_shop_add.csv',index=False)
pd.read_csv('rental_shop_add.csv')
# Out:
#       대여소번호                 대여소명  자치구                             상세주소  \
# 0       301          경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞
# 1       302          경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤
# 2       303          광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원
# 3       305               종로구청 옆  종로구               서울특별시 종로구 세종로 84-1
# 4       307            서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞
# ...     ...                  ...  ...                              ...
# 2757   3700      강변그대가리버뷰 입구 맞은편  강동구                    강동구 천호동 250-7
# 2758   3701                방아삼거리  강동구                    강동구 둔촌동 118-2
# 2759   4951   강동농협 버스정류소 앞(광채빌라)  강동구                   강동구 암사동 488-21
# 2760   4952         천호시장 버스정류소 옆  강동구                  강동구 천호동 397-465
# 2761   4953          세양청마루 아파트 앞  강동구                    강동구 천호대로 1162
#
#              위도          경도
# 0     37.575794  126.971451
# 1     37.575947  126.974060
# ...

# %% [markdown]
# 서울특별시 공공자전거 이용정보(시간대별) 전처리

# %%
usage=pd.read_csv('/content/서울특별시 공공자전거 이용정보(시간대별)_2312.csv',encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-8e3d95921b68> in <cell line: 1>()
# ----> 1 usage=pd.read_csv('/content/서울특별시 공공자전거 이용정보(시간대별)_2312.csv',encoding='euc-kr')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
usage.head()
# Out:
#          대여일자  대여시간  대여소번호                 대여소명 대여구분코드   성별 연령대코드  이용건수  \
# 0  2023-12-01     0   3517          3517. 용마사거리    정기권  NaN  ~10대     1
# 1  2023-12-01     0   1569         1569.수유역2번출구    정기권  NaN  ~10대     1
# 2  2023-12-01     0    736           736. 오솔길공원    정기권  NaN   20대     1
# 3  2023-12-01     0    740            740. 으뜸공원    정기권  NaN   20대     1
# 4  2023-12-01     0    505  505. 자양사거리 광진아크로텔 앞    정기권  NaN   20대     1
#
#      운동량   탄소량     이동거리
# 0   6.88  0.40  1738.19
# 1  78.37  0.61  2638.76
# 2  40.91  0.32  1377.52
# 3  90.50  0.53  2285.26
# 4  21.38  0.21   900.00

# %%
usage.tail()
# Out:
#                대여일자  대여시간  대여소번호              대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 1954954  2023-12-31    23   1526    1526. 강북종합시장 앞    정기권  M    기타     1
# 1954955  2023-12-31    23   1986     1986. 태평양물산빌딩    정기권  M    기타     1
# 1954956  2023-12-31    23    293       293. 충북 미래관    정기권  M    기타     1
# 1954957  2023-12-31    23    779  779. 신정1동 주민센터 앞    정기권  M    기타     1
# 1954958  2023-12-31    23    122     122. 신성기사식당 앞    정기권  M    기타     1
#
#            운동량   탄소량     이동거리
# 1954954  37.36  0.26  1110.00
# 1954955  20.29  0.18   776.29
# 1954956  14.67  0.12   529.22
# 1954957  87.44  0.64  2760.00
# 1954958  44.22  0.33  1431.63

# %%
print(rental_shop.isna().sum())
# Out:
# 대여소번호       0
# 대여소명        0
# 자치구         0
# 상세주소        0
# 위도          0
# 경도          0
# 설치시         0
# LCD      1308
# QR       1109
# 운영방식        0
# dtype: int64

# %%
print(usage.isna().sum())
# Out:
# 대여일자           0
# 대여시간           0
# 대여소번호          0
# 대여소명           0
# 대여구분코드         0
# 성별        561781
# 연령대코드          0
# 이용건수           0
# 운동량         7717
# 탄소량         7717
# 이동거리           0
# dtype: int64

# %%
usage=usage.drop(columns='성별')

# %%
def station_name(text):
    parts = text.split('.', 1)
    if len(parts) > 1:
        return parts[1].strip()
    else:
        return text.strip()

usage['대여소명'] = usage['대여소명'].apply(station_name)
usage.head()
# Out:
#          대여일자  대여시간  대여소번호            대여소명 대여구분코드 연령대코드  이용건수    운동량   탄소량  \
# 0  2023-12-01     0   3517           용마사거리    정기권  ~10대     1   6.88  0.40
# 1  2023-12-01     0   1569         수유역2번출구    정기권  ~10대     1  78.37  0.61
# 2  2023-12-01     0    736           오솔길공원    정기권   20대     1  40.91  0.32
# 3  2023-12-01     0    740            으뜸공원    정기권   20대     1  90.50  0.53
# 4  2023-12-01     0    505  자양사거리 광진아크로텔 앞    정기권   20대     1  21.38  0.21
#
#       이동거리
# 0  1738.19
# 1  2638.76
# 2  1377.52
# 3  2285.26
# 4   900.00

# %%
usage.to_csv('hour_usage.csv',index=False)
pd.read_csv('hour_usage.csv')
# Out:
#                대여일자  대여시간  대여소번호            대여소명 대여구분코드 연령대코드  이용건수    운동량  \
# 0        2023-12-01     0   3517           용마사거리    정기권  ~10대     1   6.88
# 1        2023-12-01     0   1569         수유역2번출구    정기권  ~10대     1  78.37
# 2        2023-12-01     0    736           오솔길공원    정기권   20대     1  40.91
# 3        2023-12-01     0    740            으뜸공원    정기권   20대     1  90.50
# 4        2023-12-01     0    505  자양사거리 광진아크로텔 앞    정기권   20대     1  21.38
# ...             ...   ...    ...             ...    ...   ...   ...    ...
# 1954954  2023-12-31    23   1526        강북종합시장 앞    정기권    기타     1  37.36
# 1954955  2023-12-31    23   1986         태평양물산빌딩    정기권    기타     1  20.29
# 1954956  2023-12-31    23    293          충북 미래관    정기권    기타     1  14.67
# 1954957  2023-12-31    23    779     신정1동 주민센터 앞    정기권    기타     1  87.44
# 1954958  2023-12-31    23    122        신성기사식당 앞    정기권    기타     1  44.22
#
#           탄소량     이동거리
# 0        0.40  1738.19
# ...

# %% [markdown]
# 서울특별시 공공자전거 이용정보(월별) 전처리

# %%
month_usage=pd.read_csv('/content/서울특별시_공공자전거_이용정보(월별)_23.7-12.csv',encoding='cp949')

# %%
month_usage.head()
# Out:
#      대여년월  대여소번호             대여소명 대여구분코드   성별 연령대코드  이용건수       운동량    탄소량  \
# 0  202307    102  102. 망원역 1번출구 앞    일일권  NaN   20대   166  13506.22  121.1
# 1  202307    102  102. 망원역 1번출구 앞    일일권  NaN   30대    40   2888.06  24.84
# 2  202307    102  102. 망원역 1번출구 앞    일일권  NaN   40대    13    752.19   6.75
# 3  202307    102  102. 망원역 1번출구 앞    일일권  NaN   50대     4    261.72   2.05
# 4  202307    102  102. 망원역 1번출구 앞    일일권  NaN  ~10대     5    461.54   4.02
#
#      이용거리(M)  이용시간(분)
# 0  522132.41     5076
# 1  107055.57     1407
# 2   29146.67      252
# 3    8850.00       80
# 4   17341.38      150

# %%
month_usage.isnull().sum()
# Out:
# 대여년월            0
# 대여소번호           0
# 대여소명            0
# 대여구분코드          0
# 성별         204445
# 연령대코드           0
# 이용건수            0
# 운동량             0
# 탄소량             0
# 이용거리(M)         0
# 이용시간(분)         0
# dtype: int64

# %%
month_usage=month_usage.drop(columns='성별')

# %%
usage_12=month_usage[month_usage['대여년월']==202312]

# %%
usage_12.reset_index(inplace=True,drop=True)

# %%
usage_12.head()
# Out:
#      대여년월  대여소번호             대여소명 대여구분코드 연령대코드  이용건수      운동량    탄소량  \
# 0  202312    102  102. 망원역 1번출구 앞    일일권   20대    38  2338.03  23.61
# 1  202312    102  102. 망원역 1번출구 앞    일일권   30대    20  1272.34  10.82
# 2  202312    102  102. 망원역 1번출구 앞    일일권   40대     3   149.55   1.39
# 3  202312    102  102. 망원역 1번출구 앞    일일권   60대     1   121.97   1.62
# 4  202312    102  102. 망원역 1번출구 앞    일일권  ~10대     1    44.26   0.48
#
#      이용거리(M)  이용시간(분)
# 0  101761.54     1414
# 1   51448.03      490
# 2    5993.29       42
# 3    7000.00       51
# 4    2070.00       16

# %%
def station_name(text):
    parts = text.split('.', 1)
    if len(parts) > 1:
        return parts[1].strip()
    else:
        return text.strip()

usage_12['대여소명'] = usage_12['대여소명'].apply(station_name)
usage_12.head()
# Out:
# <ipython-input-25-1fd35a3d593d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usage_12['대여소명'] = usage_12['대여소명'].apply(station_name)
#      대여년월  대여소번호        대여소명 대여구분코드 연령대코드  이용건수      운동량    탄소량    이용거리(M)  \
# 0  202312    102  망원역 1번출구 앞    일일권   20대    38  2338.03  23.61  101761.54
# 1  202312    102  망원역 1번출구 앞    일일권   30대    20  1272.34  10.82   51448.03
# 2  202312    102  망원역 1번출구 앞    일일권   40대     3   149.55   1.39    5993.29
# 3  202312    102  망원역 1번출구 앞    일일권   60대     1   121.97   1.62    7000.00
# 4  202312    102  망원역 1번출구 앞    일일권  ~10대     1    44.26   0.48    2070.00
#
#    이용시간(분)
# 0     1414
# 1      490
# 2       42
# 3       51
# 4       16

# %%
usage_12.to_csv('usage_12.csv',index=False)
pd.read_csv('usage_12.csv')
# Out:
#          대여년월  대여소번호        대여소명 대여구분코드  연령대코드  이용건수      운동량    탄소량  \
# 0      202312    102  망원역 1번출구 앞    일일권    20대    38  2338.03  23.61
# 1      202312    102  망원역 1번출구 앞    일일권    30대    20  1272.34  10.82
# 2      202312    102  망원역 1번출구 앞    일일권    40대     3   149.55   1.39
# 3      202312    102  망원역 1번출구 앞    일일권    60대     1   121.97   1.62
# 4      202312    102  망원역 1번출구 앞    일일권   ~10대     1    44.26   0.48
# ...       ...    ...         ...    ...    ...   ...      ...    ...
# 93338  202312   6172    가양5단지아파트    정기권    30대     3   142.02   0.98
# 93339  202312   6172    가양5단지아파트    정기권    60대     1     5.18   0.05
# 93340  202312   6172    가양5단지아파트    정기권  70대이상     3   410.55   4.01
# 93341  202312   6172    가양5단지아파트    정기권   ~10대     1    40.55    0.3
# 93342  202312   6172    가양5단지아파트    정기권     기타     1    46.37   0.43
#
#          이용거리(M)  이용시간(분)
# 0      101761.54     1414
# 1       51448.03      490
# 2        5993.29       42
# 3        7000.00       51
# ...

# %% [markdown]
# 서울교통공사 역주소 및 전화번호 전처리

# %%
subway=pd.read_csv('/content/서울교통공사 역주소 및 전화번호_20230831.csv',encoding='cp949')

# %%
subway.head()
# Out:
#    연번  역번호  호선    역명         역전화번호                       도로명주소  \
# 0   1  150   1    서울  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1   2  151   1    시청  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 2   3  152   1    종각  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
# 3   4  153   1  종로3가  02-6110-1301    서울특별시 종로구 종로 지하129(종로3가)
# 4   5  154   1  종로5가  02-6110-1291    서울특별시 종로구 종로 지하216(종로5가)
#
#                              지번주소
# 0   서울특별시 중구 남대문로5가 73-6 서울역(1호선)
# 1        서울특별시 중구 정동 5-5 시청역(1호선)
# 2      서울특별시 종로구 종로1가 54 종각역(1호선)
# 3  서울특별시 종로구 종로3가 10-5 종로3가역(1호선)
# 4  서울특별시 종로구 종로5가 82-1 종로5가역(1호선)

# %%
import requests
import pandas as pd
import re

# Kakao Maps API 키
kakao_api_key = '95745e119651774263dd70a3d282cbce'  # 여기에 유효한 Kakao Maps API 키를 입력하세요



# 주소를 위도와 경도로 변환하는 함수
def geocode_address(address):
    try:

        url = f'https://dapi.kakao.com/v2/local/search/address.json?query={address}'
        headers = {'Authorization': f'KakaoAK {kakao_api_key}'}
        response = requests.get(url, headers=headers)
        data = response.json()
        if data['documents']:
            latitude = data['documents'][0]['y']
            longitude = data['documents'][0]['x']
            return latitude, longitude
        else:
            print(f"주소를 찾을 수 없습니다: {address}")
            return None, None
    except Exception as e:
        print(f"Geocoding error for address {address}: {e}")
        return None, None

# '도로명 주소' 칼럼을 사용하여 위도와 경도 추가
subway['위도'], subway['경도'] = zip(*subway['도로명주소'].apply(geocode_address))

subway.head()
# Out:
#    연번  역번호  호선    역명         역전화번호                       도로명주소  \
# 0   1  150   1    서울  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1   2  151   1    시청  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 2   3  152   1    종각  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
# 3   4  153   1  종로3가  02-6110-1301    서울특별시 종로구 종로 지하129(종로3가)
# 4   5  154   1  종로5가  02-6110-1291    서울특별시 종로구 종로 지하216(종로5가)
#
#                              지번주소                위도                경도
# 0   서울특별시 중구 남대문로5가 73-6 서울역(1호선)  37.5571594835988  126.972554606456
# 1        서울특별시 중구 정동 5-5 시청역(1호선)  37.5654385176408  126.976983237511
# 2      서울특별시 종로구 종로1가 54 종각역(1호선)  37.5702140381269  126.983239678933
# 3  서울특별시 종로구 종로3가 10-5 종로3가역(1호선)  37.5704266025836   126.99202930223
# 4  서울특별시 종로구 종로5가 82-1 종로5가역(1호선)  37.5709075371016  127.001916647342

# %%
subway.head()
# Out:
#    연번  역번호  호선    역명         역전화번호                       도로명주소  \
# 0   1  150   1    서울  02-6110-1331  서울특별시 중구 세종대로 지하2(남대문로 5가)
# 1   2  151   1    시청  02-6110-1321     서울특별시 중구 세종대로 지하101(정동)
# 2   3  152   1    종각  02-6110-1311     서울특별시 종로구 종로 지하55(종로1가)
# 3   4  153   1  종로3가  02-6110-1301    서울특별시 종로구 종로 지하129(종로3가)
# 4   5  154   1  종로5가  02-6110-1291    서울특별시 종로구 종로 지하216(종로5가)
#
#                              지번주소                위도                경도
# 0   서울특별시 중구 남대문로5가 73-6 서울역(1호선)  37.5571594835988  126.972554606456
# 1        서울특별시 중구 정동 5-5 시청역(1호선)  37.5654385176408  126.976983237511
# 2      서울특별시 종로구 종로1가 54 종각역(1호선)  37.5702140381269  126.983239678933
# 3  서울특별시 종로구 종로3가 10-5 종로3가역(1호선)  37.5704266025836   126.99202930223
# 4  서울특별시 종로구 종로5가 82-1 종로5가역(1호선)  37.5709075371016  127.001916647342

# %%
subway.to_csv('subway.csv',index=False)

# %%
highschool=pd.read_csv("/content/서울시 고등학교 기본정보.csv",encoding='cp949')

# %%
highschool.head()
# Out:
#   학교종류명 설립구분   표준학교코드            학교명                                영문학교명  \
# 0  고등학교   사립  7011569     미림마이스터고등학교            Mirim Meister High School
# 1  고등학교   사립  7011568      염광메디텍고등학교        Yumkwang Meditech High School
# 2  고등학교   공립  7011558  서울웹툰애니메이션고등학교  Seoul Webtoon Animation High School
# 3  고등학교   공립  7011540         솔샘고등학교                  Solsaem High School
# 4  고등학교   사립  7011539       서울동구고등학교            SEOUL DONGGOO HIGH SCHOOL
#
#       관할조직명  도로명우편번호                  도로명주소            도로명상세주소          전화번호  \
# 0  서울특별시교육청     8821      서울특별시 관악구 호암로 546         미림마이스터고등학교   02-872-4071
# 1  서울특별시교육청     1874    서울특별시 노원구 월계로45가길 9  , 염광메디텍고등학교 (월계동)   02-994-3105
# 2  서울특별시교육청     6761  서울특별시 서초구 과천대로 852-23              (방배동)  02-6011-4100
# 3  서울특별시교육청     1190      서울특별시 강북구 인수봉로 39           / 솔샘고등학교   02-982-6104
# 4  서울특별시교육청     2834     서울특별시 성북구 성북로8길 71  / 동구마케팅고등학교 (성북동)   02-762-1301
#
# ...

# %%
highschool.isnull().sum()
# Out:
# 학교종류명            0
# 설립구분             0
# 표준학교코드           0
# 학교명              0
# 영문학교명            0
# 관할조직명            0
# 도로명우편번호          0
# 도로명주소            0
# 도로명상세주소          0
# 전화번호             0
# 홈페이지주소           0
# 팩스번호             0
# 남녀공학구분명          0
# 고등학교구분명          0
# 산업체특별학급존재여부      0
# 고등학교일반실업구분명      0
# 특수목적고등학교계열명    297
# 입시전후기구분명         0
# 주야구분명            0
# 설립일자             0
# 개교기념일            0
# 시도교육청코드          0
# 시도교육청명           0
# 소재지명             0
# 적재일시             0
# dtype: int64

# %%
highschool_add=highschool.iloc[:,:8]

# %%
highschool_add.head()
# Out:
#   학교종류명 설립구분   표준학교코드            학교명                                영문학교명  \
# 0  고등학교   사립  7011569     미림마이스터고등학교            Mirim Meister High School
# 1  고등학교   사립  7011568      염광메디텍고등학교        Yumkwang Meditech High School
# 2  고등학교   공립  7011558  서울웹툰애니메이션고등학교  Seoul Webtoon Animation High School
# 3  고등학교   공립  7011540         솔샘고등학교                  Solsaem High School
# 4  고등학교   사립  7011539       서울동구고등학교            SEOUL DONGGOO HIGH SCHOOL
#
#       관할조직명  도로명우편번호                  도로명주소
# 0  서울특별시교육청     8821      서울특별시 관악구 호암로 546
# 1  서울특별시교육청     1874    서울특별시 노원구 월계로45가길 9
# 2  서울특별시교육청     6761  서울특별시 서초구 과천대로 852-23
# 3  서울특별시교육청     1190      서울특별시 강북구 인수봉로 39
# 4  서울특별시교육청     2834     서울특별시 성북구 성북로8길 71

# %%
import requests
import pandas as pd
import re

# Kakao Maps API 키
kakao_api_key = '95745e119651774263dd70a3d282cbce'  # 여기에 유효한 Kakao Maps API 키를 입력하세요



# 주소를 위도와 경도로 변환하는 함수
def geocode_address(address):
    try:

        url = f'https://dapi.kakao.com/v2/local/search/address.json?query={address}'
        headers = {'Authorization': f'KakaoAK {kakao_api_key}'}
        response = requests.get(url, headers=headers)
        data = response.json()
        if data['documents']:
            latitude = data['documents'][0]['y']
            longitude = data['documents'][0]['x']
            return latitude, longitude
        else:
            print(f"주소를 찾을 수 없습니다: {address}")
            return None, None
    except Exception as e:
        print(f"Geocoding error for address {address}: {e}")
        return None, None

# '도로명 주소' 칼럼을 사용하여 위도와 경도 추가
highschool_add['위도'], highschool_add['경도'] = zip(*highschool_add['도로명주소'].apply(geocode_address))

highschool_add.head()
# Out:
#   학교종류명 설립구분   표준학교코드            학교명                                영문학교명  \
# 0  고등학교   사립  7011569     미림마이스터고등학교            Mirim Meister High School
# 1  고등학교   사립  7011568      염광메디텍고등학교        Yumkwang Meditech High School
# 2  고등학교   공립  7011558  서울웹툰애니메이션고등학교  Seoul Webtoon Animation High School
# 3  고등학교   공립  7011540         솔샘고등학교                  Solsaem High School
# 4  고등학교   사립  7011539       서울동구고등학교            SEOUL DONGGOO HIGH SCHOOL
#
#       관할조직명  도로명우편번호                  도로명주소                위도  \
# 0  서울특별시교육청     8821      서울특별시 관악구 호암로 546  37.4661018035835
# 1  서울특별시교육청     1874    서울특별시 노원구 월계로45가길 9  37.6302844506448
# 2  서울특별시교육청     6761  서울특별시 서초구 과천대로 852-23  37.4694909673091
# 3  서울특별시교육청     1190      서울특별시 강북구 인수봉로 39  37.6237648476803
# 4  서울특별시교육청     2834     서울특별시 성북구 성북로8길 71  37.5941065881018
#
#                  경도
# 0  126.931927855676
# 1  127.049264552091
# 2  126.988245947982
# 3  127.012068855446
# 4  127.008215538987

# %%
highschool_add.to_csv('highschool_add.csv',index=False)

# %%
university=pd.read_csv('/content/서울시 대학 및 전문대학 DB 정보 (한국어).csv',encoding='cp949')

# %%
university.head()
# Out:
#                키값    연도       학교종류        학교명 본분교    학교상태  설립  우편번호  \
# 0  BE_LiST23-0034  2013       일반대학    서울시립대학교  본교      기존  공립   NaN
# 1  BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교  본교      기존  사립   NaN
# 2  BE_LiST23-0036  2013       일반대학    서울여자대학교  본교      기존  사립   NaN
# 3  BE_LiST23-0037  2013  전문대학(2년제)      서일대학교  본교  학교명 변경  사립   NaN
# 4  BE_LiST23-0038  2013       일반대학     성공회대학교  본교      기존  사립   NaN
#
#                                주소  도로명주소    행정시   행정구      행정동          전화번호  \
# 0  서울 동대문구 서울시립대로 163 (전농동 90번지)     NaN  서울특별시  동대문구     휘경2동  02-6490-6114
# 1           서울 서대문구 홍제3동 서울여자간호대학    NaN  서울특별시  서대문구     홍제2동  02-2287-1700
# 2       서울특별시 노원구 화랑로 621 서울여자대학교    NaN  서울특별시   노원구     공릉2동   02-970-5114
# 3     서울특별시 중랑구 용마산로 90길 28 서일대학교    NaN  서울특별시   중랑구  면목제3.8동   02-490-7300
# 4        서울특별시 구로구 연동로 320 성공회대학교    NaN  서울특별시   구로구     오류2동  02-2610-4142
#
#            팩스번호                    홈페이지
# 0  02-2210-5576    http://www.uos.ac.kr
# ...

# %%
university_add=university.iloc[:,2:9]

# %%
university_add.head()
# Out:
#         학교종류        학교명 본분교    학교상태  설립  우편번호                              주소
# 0       일반대학    서울시립대학교  본교      기존  공립   NaN  서울 동대문구 서울시립대로 163 (전농동 90번지)
# 1  전문대학(3년제)  서울여자간호대학교  본교      기존  사립   NaN           서울 서대문구 홍제3동 서울여자간호대학
# 2       일반대학    서울여자대학교  본교      기존  사립   NaN       서울특별시 노원구 화랑로 621 서울여자대학교
# 3  전문대학(2년제)      서일대학교  본교  학교명 변경  사립   NaN     서울특별시 중랑구 용마산로 90길 28 서일대학교
# 4       일반대학     성공회대학교  본교      기존  사립   NaN        서울특별시 구로구 연동로 320 성공회대학교

# %%
university_add=university_add.drop(columns='우편번호')

# %%
university_add.head()
# Out:
#         학교종류        학교명 본분교    학교상태  설립                              주소
# 0       일반대학    서울시립대학교  본교      기존  공립  서울 동대문구 서울시립대로 163 (전농동 90번지)
# 1  전문대학(3년제)  서울여자간호대학교  본교      기존  사립           서울 서대문구 홍제3동 서울여자간호대학
# 2       일반대학    서울여자대학교  본교      기존  사립       서울특별시 노원구 화랑로 621 서울여자대학교
# 3  전문대학(2년제)      서일대학교  본교  학교명 변경  사립     서울특별시 중랑구 용마산로 90길 28 서일대학교
# 4       일반대학     성공회대학교  본교      기존  사립        서울특별시 구로구 연동로 320 성공회대학교

# %%
import requests
import pandas as pd
import re

# Kakao Maps API 키
kakao_api_key = '95745e119651774263dd70a3d282cbce'  # 여기에 유효한 Kakao Maps API 키를 입력하세요



# 주소를 위도와 경도로 변환하는 함수
def geocode_address(address):
    try:

        url = f'https://dapi.kakao.com/v2/local/search/address.json?query={address}'
        headers = {'Authorization': f'KakaoAK {kakao_api_key}'}
        response = requests.get(url, headers=headers)
        data = response.json()
        if data['documents']:
            latitude = data['documents'][0]['y']
            longitude = data['documents'][0]['x']
            return latitude, longitude
        else:
            print(f"주소를 찾을 수 없습니다: {address}")
            return None, None
    except Exception as e:
        print(f"Geocoding error for address {address}: {e}")
        return None, None

# '도로명 주소' 칼럼을 사용하여 위도와 경도 추가
university_add['위도'], university_add['경도'] = zip(*university_add['주소'].apply(geocode_address))

university_add.head()
# Out:
#         학교종류        학교명 본분교    학교상태  설립                              주소  \
# 0       일반대학    서울시립대학교  본교      기존  공립  서울 동대문구 서울시립대로 163 (전농동 90번지)
# 1  전문대학(3년제)  서울여자간호대학교  본교      기존  사립           서울 서대문구 홍제3동 서울여자간호대학
# 2       일반대학    서울여자대학교  본교      기존  사립       서울특별시 노원구 화랑로 621 서울여자대학교
# 3  전문대학(2년제)      서일대학교  본교  학교명 변경  사립     서울특별시 중랑구 용마산로 90길 28 서일대학교
# 4       일반대학     성공회대학교  본교      기존  사립        서울특별시 구로구 연동로 320 성공회대학교
#
#                  위도                경도
# 0  37.5825775765293  127.059988126984
# 1   37.597029954835  126.956476606594
# 2  37.6273815936787  127.091621159803
# 3  37.5860827979004  127.097203310115
# 4  37.4875235978289  126.826163535057

# %%
university_add.to_csv('university_add.csv',index=False)

# %% [markdown]
# 자치구별 이용건수 확인

# %%
import pandas as pd
rental_shop_add=pd.read_csv('rental_shop_add.csv',encoding='cp949')
usage_12=pd.read_csv('usage_12.csv')

# %%
rental_shop_add.head()
# Out:
#    대여소번호          대여소명  자치구                             상세주소         위도  \
# 0    301   경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞  37.575794
# 1    302   경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤  37.575947
# 2    303   광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원  37.571770
# 3    305        종로구청 옆  종로구               서울특별시 종로구 세종로 84-1  37.572559
# 4    307     서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞  37.570000
#
#            경도
# 0  126.971451
# 1  126.974060
# 2  126.974663
# 3  126.978332
# 4  126.971100

# %%
usage_12.head()
# Out:
#      대여년월  대여소번호        대여소명 대여구분코드 연령대코드  이용건수      운동량    탄소량    이용거리(M)  \
# 0  202312    102  망원역 1번출구 앞    일일권   20대    38  2338.03  23.61  101761.54
# 1  202312    102  망원역 1번출구 앞    일일권   30대    20  1272.34  10.82   51448.03
# 2  202312    102  망원역 1번출구 앞    일일권   40대     3   149.55   1.39    5993.29
# 3  202312    102  망원역 1번출구 앞    일일권   60대     1   121.97   1.62    7000.00
# 4  202312    102  망원역 1번출구 앞    일일권  ~10대     1    44.26   0.48    2070.00
#
#    이용시간(분)
# 0     1414
# 1      490
# 2       42
# 3       51
# 4       16

# %%
usage_12 = usage_12.merge(rental_shop_add[['대여소번호', '자치구']], on='대여소번호', how='left')
usage_12.head()
# Out:
#      대여년월  대여소번호        대여소명 대여구분코드 연령대코드  이용건수      운동량    탄소량    이용거리(M)  \
# 0  202312    102  망원역 1번출구 앞    일일권   20대    38  2338.03  23.61  101761.54
# 1  202312    102  망원역 1번출구 앞    일일권   30대    20  1272.34  10.82   51448.03
# 2  202312    102  망원역 1번출구 앞    일일권   40대     3   149.55   1.39    5993.29
# 3  202312    102  망원역 1번출구 앞    일일권   60대     1   121.97   1.62    7000.00
# 4  202312    102  망원역 1번출구 앞    일일권  ~10대     1    44.26   0.48    2070.00
#
#    이용시간(분)  자치구
# 0     1414  마포구
# 1      490  마포구
# 2       42  마포구
# 3       51  마포구
# 4       16  마포구

# %%
usage_12.to_csv('usage_12.csv',index=False)
